# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### Health Department Food Inspection Tracker
#
# 1. Go to the Chicago Data Portal: https://data.cityofchicago.org/
# 2. Find each dataset. Building violations, ward, and police.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
hd = pd.read_csv("https://data.cityofchicago.org/resource/4ijn-s7e5.csv?$limit=500000")
# you can use any of these
ward = gpd.read_file('https://data.cityofchicago.org/api/geospatial/sp34-6z76?method=export&format=GeoJSON')
police = gpd.read_file('https://data.cityofchicago.org/api/geospatial/fthy-xz3r?method=export&format=GeoJSON')

# %%
hd.head()
# Out:
#    inspection_id                         dba_name  \
# 0        2592298                   MODA FOOD MART
# 1        2592288      GARRETT POPCORN SHOP MDW-CM
# 2        2592295   DRAFT KINGS FANTASY SPORTS BAR
# 3        2592283             GIORDANO'S GREEKTOWN
# 4        2592307  LOTUS CAFE & BANH MI SANDWICHES
#
#                           aka_name   license_  facility_type             risk  \
# 0                   MODA FOOD MART  2956273.0  Grocery Store  Risk 2 (Medium)
# 1      GARRETT POPCORN SHOP MDW-CM  2872808.0     Restaurant  Risk 2 (Medium)
# 2                      DRAFT KINGS  2078712.0     Restaurant  Risk 2 (Medium)
# 3             GIORDANO'S GREEKTOWN  2412589.0     Restaurant    Risk 1 (High)
# 4  LOTUS CAFE & BANH MI SANDWICHES  2184200.0     Restaurant    Risk 1 (High)
#
#               address     city state      zip          inspection_date  \
# 0  559 N LARAMIE AVE   CHICAGO    IL  60644.0  2024-04-08T00:00:00.000
# 1  5700 S CICERO AVE   CHICAGO    IL  60638.0  2024-04-08T00:00:00.000
# 2  1060 W ADDISON ST   CHICAGO    IL  60613.0  2024-04-08T00:00:00.000
# 3    815 W VAN BUREN   CHICAGO    IL  60607.0  2024-04-08T00:00:00.000
# 4   719 W MAXWELL ST   CHICAGO    IL  60607.0  2024-04-08T00:00:00.000
#
#          inspection_type          results  \
# 0                License             Pass
# 1                Canvass             Pass
# 2                Canvass  Out of Business
# 3   Short Form Complaint             Pass
# 4  Canvass Re-Inspection             Pass
#
#                                           violations   latitude  longitude  \
# 0  36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.891034 -87.755310
# 1                                                NaN  41.789329 -87.741646
# 2                                                NaN  41.947317 -87.656418
# 3                                                NaN  41.876552 -87.647870
# 4                                                NaN  41.864687 -87.645821
#
#                                    location
# 0  (41.891033547074734, -87.75530964570335)
# 1  (41.789329323265385, -87.74164564419637)
# 2   (41.94731748901495, -87.65641794764645)
# 3   (41.87655166174297, -87.64786970336469)
# 4   (41.86468702282133, -87.64582096372712)

# %%
police.head()
# Out:
#   dist_label dist_num                                           geometry
# 0       17TH       17  MULTIPOLYGON (((-87.71067 41.99737, -87.71067 ...
# 1       20TH       20  MULTIPOLYGON (((-87.66029 41.99092, -87.66029 ...
# 2       31ST       31  MULTIPOLYGON (((-87.82818 41.98384, -87.82816 ...
# 3       31ST       31  MULTIPOLYGON (((-87.83365 41.97535, -87.83366 ...
# 4       19TH       19  MULTIPOLYGON (((-87.64492 41.96973, -87.64431 ...

# %%
police.head()
# Out:
#   dist_label dist_num                                           geometry
# 0       17TH       17  MULTIPOLYGON (((-87.71067 41.99737, -87.71067 ...
# 1       20TH       20  MULTIPOLYGON (((-87.66029 41.99092, -87.66029 ...
# 2       31ST       31  MULTIPOLYGON (((-87.82818 41.98384, -87.82816 ...
# 3       31ST       31  MULTIPOLYGON (((-87.83365 41.97535, -87.83366 ...
# 4       19TH       19  MULTIPOLYGON (((-87.64492 41.96973, -87.64431 ...
